# %%
import pandas as pd

movies = {
    "title": ["Inception", "Interstellar", "The Dark Knight", "Titanic", "Avatar"],
    "genre": ["Sci-Fi", "Sci-Fi", "Action", "Romance", "Adventure"],
    "year": [2010, 2014, 2008, 1997, 2009]
}

df = pd.DataFrame(movies)

print("Dataset Shape:", df.shape)
print(df.head())
# Out:
# Dataset Shape: (5, 3)
#              title      genre  year
# 0        Inception     Sci-Fi  2010
# 1     Interstellar     Sci-Fi  2014
# 2  The Dark Knight     Action  2008
# 3          Titanic    Romance  1997
# 4           Avatar  Adventure  2009

# %%
import os
print(os.getcwd())
# Out:
# /content
